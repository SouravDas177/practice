# %% [markdown]
# <a href="https://colab.research.google.com/github/SouravDas177/practice/blob/main/placement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/CollegePlacement.csv")

# %%
df.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# ...

# %%
df=df.drop(["College_ID","Prev_Sem_Result"],axis=1)

# %%
df.head()
# Out:
#     IQ  CGPA  Academic_Performance Internship_Experience  \
# 0  107  6.28                     8                    No
# 1   97  5.37                     8                    No
# 2  109  5.83                     9                    No
# 3  122  5.75                     6                   Yes
# 4   96  7.69                     7                    No
#
#    Extra_Curricular_Score  Communication_Skills  Projects_Completed Placement
# 0                       8                     8                   4        No
# 1                       7                     8                   0        No
# 2                       3                     1                   1        No
# 3                       1                     6                   1        No
# 4                       8                    10                   2        No

# %%
df.isnull().sum()
# Out:
# IQ                        0
# CGPA                      0
# Academic_Performance      0
# Internship_Experience     0
# Extra_Curricular_Score    0
# Communication_Skills      0
# Projects_Completed        0
# Placement                 0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df["Internship_Experience"]=df["Internship_Experience"].map({"No":0,"Yes":1})

# %%
encoder=LabelEncoder()

# %%
df["Placement"]=encoder.fit_transform(df["Placement"])

# %%
df.head()
# Out:
#     IQ  CGPA  Academic_Performance  Internship_Experience  \
# 0  107  6.28                     8                      0
# 1   97  5.37                     8                      0
# 2  109  5.83                     9                      0
# 3  122  5.75                     6                      1
# 4   96  7.69                     7                      0
#
#    Extra_Curricular_Score  Communication_Skills  Projects_Completed  Placement
# 0                       8                     8                   4          0
# 1                       7                     8                   0          0
# 2                       3                     1                   1          0
# 3                       1                     6                   1          0
# 4                       8                    10                   2          0

# %%
df.shape
# Out:
# (10000, 8)

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df["IQ"].skew()
# Out:
# np.float64(0.0006980358713895958)

# %%
sns.distplot(df["IQ"])
# Out:
# /tmp/ipython-input-2445848997.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["IQ"])
# <Axes: xlabel='IQ', ylabel='Density'>

# %%
df["CGPA"].skew()
# Out:
# np.float64(-0.03291311905857653)

# %%
sns.distplot(df["CGPA"])
# Out:
# /tmp/ipython-input-4104398760.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["CGPA"])
# <Axes: xlabel='CGPA', ylabel='Density'>

# %%
sns.histplot(df["Academic_Performance"])
# Out:
# <Axes: xlabel='Academic_Performance', ylabel='Count'>

# %%
sns.histplot(df["Internship_Experience"])
# Out:
# <Axes: xlabel='Internship_Experience', ylabel='Count'>

# %%
sns.histplot(df["Extra_Curricular_Score"])
# Out:
# <Axes: xlabel='Extra_Curricular_Score', ylabel='Count'>

# %%
sns.histplot(df["Projects_Completed"])
# Out:
# <Axes: xlabel='Projects_Completed', ylabel='Count'>

# %%
sns.scatterplot(x=df["CGPA"],y=df["IQ"])
# Out:
# <Axes: xlabel='CGPA', ylabel='IQ'>

# %%
df["Placement"].value_counts()
# Out:
# Placement
# 0    8341
# 1    1659
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                  IQ          CGPA  Academic_Performance  \
# count  10000.000000  10000.000000          10000.000000
# mean      99.471800      7.532379              5.546400
# std       15.053101      1.470141              2.873477
# min       41.000000      4.540000              1.000000
# 25%       89.000000      6.290000              3.000000
# 50%       99.000000      7.550000              6.000000
# 75%      110.000000      8.770000              8.000000
# max      158.000000     10.460000             10.000000
#
#        Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# count           10000.000000            10000.000000          10000.000000
# mean                0.396400                4.970900              5.561800
# std                 0.489174                3.160103              2.900866
# min                 0.000000                0.000000              1.000000
# 25%                 0.000000                2.000000              3.000000
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report

# %%
x=df.drop("Placement",axis=1)
y=df["Placement"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LogisticRegression()

# %%
model.fit (x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
acc=accuracy_score(y_test,y_pred)
print(acc)
# Out:
# 0.895

# %%
plt.scatter(df["Placement"],df["CGPA"],c=y)

# %%
plt.scatter(df["IQ"],df["CGPA"],c=y)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94      1674
#            1       0.71      0.61      0.65       326
#
#     accuracy                           0.90      2000
#    macro avg       0.82      0.78      0.80      2000
# weighted avg       0.89      0.90      0.89      2000
